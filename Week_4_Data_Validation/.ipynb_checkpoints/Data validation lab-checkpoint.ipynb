# %%
import pandas as pd
import pandas.api.types as ptypes

df = pd.read_csv("data.csv")

# %%
df.head()
# Out:
#    Crash ID  Record Type  Vehicle ID  Participant ID  \
# 0   1809119            1         NaN             NaN
# 1   1809119            2   3409578.0             NaN
# 2   1809119            3   3409578.0       3887884.0
# 3   1809119            2   3409579.0             NaN
# 4   1809119            3   3409579.0       3887885.0
#
#    Participant Display Seq#  Vehicle Coded Seq#  Participant Vehicle Seq#  \
# 0                       NaN                 NaN                       NaN
# 1                       NaN                 1.0                       NaN
# 2                       1.0                 1.0                       1.0
# 3                       NaN                 2.0                       NaN
# 4                       2.0                 2.0                       1.0
#
#    Serial #  Crash Month  Crash Day  ...  Participant Cause 2 Code  \
# 0   99992.0          3.0       14.0  ...                       NaN
# ...

# %%
assert ptypes.is_numeric_dtype(df['Vehicle ID'])

# %%
if 'Vehicle ID' not in df.columns:
    print("Assertion for Vehicle ID failed!")

# %%
if 'County Code' not in df.columns:
    print("Assertion for County ID failed!")

# %%
df['Crash Month'].apply(1 <= a <= 12)
# Out:
#   File "<ipython-input-25-43ea56d64379>", line 1
#     df['Crash Month'].apply(lambda a : True if 1 <= a <= 12 else raise Exception('invalid month'))
#                                                                  ^
# SyntaxError: invalid syntax
